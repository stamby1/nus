# %%
import json
import itertools
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import LinearAxis, Range1d, BoxAnnotation

# %%
class Data(object):  # each data object contains a time, distance, and rssi value
    
    def __init__(self):
        self.time = 0
        self.distance = 0
        self.rssi = 0

# %%
# global variables
beaconNum = "0:0" 
allBeacons = {}  # dictionary of every beacon in a block
#colors = itertools.cycle(["red", "green", "yellow", "blue", "orange", "magenta", "black"])  # different colors for each beacon
#colors = itertools.cycle(["red", "blue"])  # different colors for distance and rssi
colors = itertools.cycle(["firebrick"])
x = []  # time
y = []  # distance
z = []  # rssi
average_dist = [0] * 400
average_rssi = [0] * 400
average_var = [0] * 400
begin = []
end = []
initial_time = 0

# %%
def moving_average(window):  # parameter represents window for average moving window filter
# first time frame: 0-2 seconds -> get average for second 1
# second time frame: 1-3 seconds -> get average for second 2
# keep incrementing by 1 second, but frame is [window] seconds
    global allBeacons
    global x  # list of all times
    global y  # list of all distances
    global z  # list of all rssi values
    global beaconNum
    global average_dist
    global average_rssi
    global average_var
    variance = []
    numInWindow = 0
    for i in range(400):  # for every single second 0 thru 399
        for j in range(len(x)): # loop through every single time 0 thru len(x)-1
            if x[j] >= i - (window/2) and x[j] < i + (window/2):  # if time is in proper frame
                numInWindow += 1
                average_dist[i] = average_dist[i] + y[j]
                average_rssi[i] = average_rssi[i] + z[j]
                variance.append(y[j])  # list of dist values within proper frame and for specific second
        if numInWindow > 0:
            average_dist[i] = average_dist[i] / numInWindow
            average_rssi[i] = average_rssi[i] / numInWindow
        for k in range(len(variance)):
            variance[k] = (variance[k] - average_dist[i])**2  # convert values to variance
            average_var[i] = average_var[i] + variance[k]
        average_var[i] = average_var[i] / len(variance)
        variance.clear()  # clear list for next second
        numInWindow = 0

# %%
def plot_minor():
    global allBeacons
    global beaconNum
    global colors
    global x  # times
    global y  # distances
    global z  # rssi values
    global average_dist
    global average_rssi
    global average_var
    global begin
    global end
    global initial_time
    color = next(colors)
    tempTitle="Beacon " + str(beaconNum)

    for i in range(len(allBeacons[beaconNum])):  # position in allBeacon[beaconNum] array
        x.append(allBeacons[beaconNum][i].time)
        y.append(allBeacons[beaconNum][i].distance)
        z.append(allBeacons[beaconNum][i].rssi)
    
    moving_average(4) # calculate moving average for distance and rssi in 4 second window
    
    output_notebook()
    p = figure(
        tools="pan, box_zoom, wheel_zoom, reset, resize",
        title=tempTitle, x_axis_label='Average Distance (meters)', y_axis_label='Variance',
        x_range=(min(average_dist), max(average_dist)), y_range=(min(average_var), max(average_var)),
        plot_width=900, plot_height=400
    )
    
    # plot average variances for each second
    p.scatter(
        average_dist, average_var,
        marker="circle", fill_color=color, line_color = color
    )
    
    show(p)

# %%
def get_data(i):  # open text file and extract data
    global beaconNum
    global allBeacons
    global initial_time
    
    textName = "minor" + str(i) + ".txt"
    f = open(textName)
    first = True
    for line in f:
        words = line.split()
        time = int(words[0])  # get time
        if first == True:
            initial_time = time  # set base time
            first = False
        time = (time - initial_time) / 1000  # get elapsed time in seconds
        parsed_json = json.loads(words[1])  # parse json
        beaconNum = str(parsed_json['major']) + ":" + str(parsed_json['minor'])  # beacon identified by major and minor
        rssi = parsed_json['rssi']
        distance = 10**((rssi+60)/-20)  # log-distance pathloss model
        allBeacons.setdefault(beaconNum, []).append(Data())  # each beacon has an array of Data
        dataPos = len(allBeacons[beaconNum]) - 1  # position in array
        allBeacons[beaconNum][dataPos].time = time
        allBeacons[beaconNum][dataPos].distance = distance
        allBeacons[beaconNum][dataPos].rssi = rssi
    f.close()  # close file

# %%
def get_markers():
    global begin
    global end
    m = open("markers.txt")
    for line in m:
        words = line.split()
        time = int(words[0])  # get raw time
        parsed_json = json.loads(words[1])  # parse json
        if parsed_json['marker'] == "begin\n":
            begin.append(time)
        elif parsed_json['marker'] == "end\n":
            end.append(time)
    m.close()

# %%
def main():
    get_markers()
    for i in range(7):
        get_data(i)
        plot_minor()

# %%
if __name__ == "__main__":
    main()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dd243630-2fb2-4a22-821e-650874b83ba5">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="46cc37ac-ac8f-412d-840d-9ecc61ab4c73"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("46cc37ac-ac8f-412d-840d-9ecc61ab4c73");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '46cc37ac-ac8f-412d-840d-9ecc61ab4c73' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dc5026df-a5f0-463b-9401-7c1f097228ce":{"roots":{"references":[{"attributes":{},"id":"c6c5b489-cba5-46c6-aa90-0174f1d574e5","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"3a09bfa9-6ba0-42b6-a51c-d18e488a3cfb","subtype":"Figure","type":"Plot"},"ticker":{"id":"7cf67a31-692d-4af3-b8cb-11e352ad0dec","type":"BasicTicker"}},"id":"c718dbbe-06a1-4293-b278-b54de73e711a","type":"Grid"},{"attributes":{"axis_label":"Variance","formatter":{"id":"1603dd8d-45b4-460a-be39-5e3f5bbb6d25","type":"BasicTickFormatter"},"plot":{"id":"a2493ead-074d-452e-b6f7-f0b090533534","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b927e6f-805d-4f7a-a361-de3e087ee9e3","type":"BasicTicker"}},"id":"0b91020d-a572-4064-85a8-b3ef5e92cf13","type":"LinearAxis"},{"attributes":{},"id":"cfb172c9-18a0-4a68-996f-3dfd7d8d5e00","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"navy"},"line_color":{"value":"navy"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a9f4539e-8ea9-4d84-b46e-1149811e8ca2","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b45f375e-a0ff-404b-92ef-f57f33913721","type":"BoxAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8f6431b4-b577-4789-abcb-e1694cc89bd8","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"bcd5b5be-6dcc-402b-8ed9-1db5aa2a4a96","type":"LinearAxis"}],"left":[{"id":"31f12798-0de4-4e88-9d46-b22dc016e2b3","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"bcd5b5be-6dcc-402b-8ed9-1db5aa2a4a96","type":"LinearAxis"},{"id":"4b0013aa-9b70-4ca3-b9a9-e55dcb862b57","type":"Grid"},{"id":"31f12798-0de4-4e88-9d46-b22dc016e2b3","type":"LinearAxis"},{"id":"68c69ce1-112d-48c8-8891-22f82af9059a","type":"Grid"},{"id":"0494f3a1-acb7-4abd-96cb-042b993a6ee4","type":"BoxAnnotation"},{"id":"37223192-1320-4238-9d1e-e1c33ea78941","type":"GlyphRenderer"}],"title":"Beacon 0:0","tool_events":{"id":"06cbcddc-54bf-45c7-8149-c8b9ed4f352d","type":"ToolEvents"},"tools":[{"id":"c2a17f17-f391-49e3-8aeb-f30c94793727","type":"PanTool"},{"id":"b34e8e87-1b76-4e53-8f7b-1b4921cd9a22","type":"BoxZoomTool"},{"id":"d242b099-13de-444c-ab31-3f7fb2807765","type":"WheelZoomTool"},{"id":"1f755c8a-0e4a-49ad-97bb-3257be79dceb","type":"ResetTool"},{"id":"0a5f61a6-4d16-42f4-a433-d9fea32418ad","type":"ResizeTool"}],"x_range":{"id":"e595dd21-352e-47eb-af1a-1c8fbe8f8738","type":"Range1d"},"y_range":{"id":"5086e76a-4fa1-4ffb-af8f-0c0322fdaa5d","type":"Range1d"}},"id":"3c6a669e-3d00-4393-bff7-a0c6858dc0e0","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"78ecce48-6bd3-47a8-a05e-02fd7c3c4810","subtype":"Figure","type":"Plot"}},"id":"daca79ce-1033-463b-855e-5e72b843ea16","type":"ResizeTool"},{"attributes":{"below":[{"id":"6561b56c-1226-461a-9555-4a749000ee81","type":"LinearAxis"}],"left":[{"id":"c20f9b98-1795-4341-a8ac-6db2cb68d444","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"6561b56c-1226-461a-9555-4a749000ee81","type":"LinearAxis"},{"id":"3606ef4e-2810-465d-99c5-6b573ae55665","type":"Grid"},{"id":"c20f9b98-1795-4341-a8ac-6db2cb68d444","type":"LinearAxis"},{"id":"472cf74c-e341-4ff7-9fa3-2216904cc93e","type":"Grid"},{"id":"5310845a-b9a7-4558-914b-1d41baf1e4ac","type":"BoxAnnotation"},{"id":"eb66cf96-94ce-45fa-9dd4-8bd4504a32aa","type":"GlyphRenderer"}],"title":"Beacon 0:4","tool_events":{"id":"4c5c45a2-b6f1-49cb-a539-7a4b6884cd1c","type":"ToolEvents"},"tools":[{"id":"9997e417-fbf2-424 ...
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="650ed66b-13f9-45dc-9d30-4eb1a1511d55">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="aa59c9c9-6a28-4092-ac85-d64fe8324520"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aa59c9c9-6a28-4092-ac85-d64fe8324520");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aa59c9c9-6a28-4092-ac85-d64fe8324520' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"73e7076a-5348-439b-a342-6a7cc580b71e":{"roots":{"references":[{"attributes":{},"id":"c6c5b489-cba5-46c6-aa90-0174f1d574e5","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"3a09bfa9-6ba0-42b6-a51c-d18e488a3cfb","subtype":"Figure","type":"Plot"},"ticker":{"id":"7cf67a31-692d-4af3-b8cb-11e352ad0dec","type":"BasicTicker"}},"id":"c718dbbe-06a1-4293-b278-b54de73e711a","type":"Grid"},{"attributes":{"axis_label":"Variance","formatter":{"id":"1603dd8d-45b4-460a-be39-5e3f5bbb6d25","type":"BasicTickFormatter"},"plot":{"id":"a2493ead-074d-452e-b6f7-f0b090533534","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b927e6f-805d-4f7a-a361-de3e087ee9e3","type":"BasicTicker"}},"id":"0b91020d-a572-4064-85a8-b3ef5e92cf13","type":"LinearAxis"},{"attributes":{},"id":"cfb172c9-18a0-4a68-996f-3dfd7d8d5e00","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"navy"},"line_color":{"value":"navy"},"x":{"field":"x"},"y":{"field":"y"}},"id":"
cb6ba7a","type":"GlyphRenderer"}],"title":"Beacon 0:3","tool_events":{"id":"5a289a88-8192-47f7-9220-caea79089994","type":"ToolEvents"},"tools":[{"id":"92c2a188-f4a3-4f5d-a50c-81a6f7fdc0cc","type":"PanTool"},{"id":"2127a694-4028-4db9-8fa0-3be7935761cb","type":"BoxZoomTool"},{"id":"63954ef8-b47e-4d2a-b031-af7de2ddeebd","type":"WheelZoomTool"},{"id":"f6b9689e-b431-4d74-b53c-25e2fce445b5","type":"ResetTool"},{"id":"d78d0d8b-8510-4c42-9c35-b11b11a3f27c","type":"ResizeTool"}],"x_range":{"id":"c2760c93-d343-46fc-866e-891dc44ed20a","type":"Range1d"},"y_range":{"id":"cbf93174-cb4c-4aee-8f33-41f72de74f84","type":"Range1d"}},"id":"3a9ab09e-683f-47e1-ae33-50712cddbfd0","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"b966454a-b202-4794-aa2d-4b59e3909446","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"bcd5b5be-6dcc-402b-8ed9-1db5aa2a4a96","type":"LinearAxis"}],"left":[{"id":"31f12798-0de4-4e88-9d46-b22dc016e2b3","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"bcd5b5be-6dcc-402b-8ed9-1db5aa2a4a96","type":"LinearAxis"},{"id":"4b0013aa-9b70-4ca3-b9a9-e55dcb862b57","type":"Grid"},{"id":"31f12798-0de4-4e88-9d46-b22dc016e2b3","type":"LinearAxis"},{"id":"68c69ce1-112d-48c8-8891-22f82af9059a","type":"Grid"},{"id":"0494f3a1-acb7-4abd-96cb-042b993a6ee4","type":"BoxAnnotation"},{"id":"37223192-1320-4238-9d1e-e1c33ea78941","type":"GlyphRenderer"}],"title":"Beacon 0:0","tool_events":{"id":"06cbcddc-54bf-45c7-8149-c8b9ed4f352d","type":"ToolEvents"},"tools":[{"id":"c2a17f17-f391-49e3-8aeb-f30c94793727","type":"PanTool"},{"id":"b34e8e87-1b76-4e53-8f7b-1b4921cd9a22","type":"BoxZoomTool"},{"id":"d242b099-13de-444c-ab31-3f7fb2807765","type":"WheelZoomTool"},{"id":"1f755c8a-0e4a-49ad-97bb-3257be79dceb","type":"ResetTool"},{"id":"0a5f61a6-4d16-42f4-a433-d9fea32418ad","type":"ResizeTool"}],"x_range":{"id":"e595dd21-352e-47eb-af1a-1c8fbe8f8738","type":"Range1d"}," ...
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2a1d65c3-4265-4fdf-8291-015c0ae04cab">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="f2ca9a70-8fff-4a7c-a42d-1e588d8205ba"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2ca9a70-8fff-4a7c-a42d-1e588d8205ba");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2ca9a70-8fff-4a7c-a42d-1e588d8205ba' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1fbc2833-0992-45eb-ac18-7ac69bda36c3":{"roots":{"references":[{"attributes":{"axis_label":"Variance","formatter":{"id":"a9d5afdb-9158-4971-990c-59939011eb98","type":"BasicTickFormatter"},"plot":{"id":"471e951e-2c74-4c95-9c72-01a26e886c5a","subtype":"Figure","type":"Plot"},"ticker":{"id":"71d52991-182e-487c-b992-0b5a87eed166","type":"BasicTicker"}},"id":"7569e9de-4161-45a3-9d12-393b4f7b4048","type":"LinearAxis"},{"attributes":{},"id":"c6c5b489-cba5-46c6-aa90-0174f1d574e5","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="776ebc2d-db4a-41bf-a3d1-3ff5d8161e2d">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="84714ae5-2761-4ca6-a53f-6c88da44f49a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("84714ae5-2761-4ca6-a53f-6c88da44f49a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '84714ae5-2761-4ca6-a53f-6c88da44f49a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"11063a4e-a308-41d7-b14b-34b383c3156a":{"roots":{"references":[{"attributes":{"axis_label":"Variance","formatter":{"id":"ee20d5fb-3a6c-4ed4-868c-3e3b58fbff40","type":"BasicTickFormatter"},"plot":{"id":"3a9ab09e-683f-47e1-ae33-50712cddbfd0","subtype":"Figure","type":"Plot"},"ticker":{"id":"6b28789b-8557-49a1-8925-254c6c760b3d","type":"BasicTicker"}},"id":"489ee919-8733-4644-805c-5d6d7c41e667","type":"LinearAxis"},{"attributes":{"axis_label":"Variance","formatter":{"id":"a9d5afdb-9158-4971-990c-59939011eb98","type":"BasicTickFormatter"},"plot":{"id":"471e951e-2c74-4c95-9c72-01a26e886c5a","subtype":"Figure","type":"Plot"},"ticker":{"id":"71d52991-182e-487c-b992-0b5a87eed166","type":"BasicTicker"}},"id":"7569e9de-4161-45a3-9d12-393b4f7b4048","type":"LinearAxis"},{"attributes":{"below":[{"id":"bcd5b5be-6dcc-402b-8ed9-1db5aa2a4a96","type":"LinearAxis"}],"left":[{"id":"31f12798-0de4-4e88-9d46-b22dc016e2b3","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"bcd5b5be-6dcc-402b-8ed9-1db5aa2a4a96","type":"LinearAxis"},{"id":"4b0013aa-9b70-4ca3-b9a9-e55dcb862b57","type":"Grid"},{"id":"31f12798-0de4-4e88-9d46-b22dc016e2b3","type":"LinearAxis"},{"id":"68c69ce1-112d-48c8-8891-22f82af9059a","type":"Grid"},{"id":"0494f3a1-acb7-4abd-96cb-042b993a6ee4","type":"BoxAnnotation"},{"id":"37223192-1320-4238-9d1e-e1c33ea78941","type":"GlyphRenderer"}],"title":"Beacon 0:0","tool_events":{"id":"06cbcddc-54bf-45c7-8149-c8b9ed4f352d","type":"ToolEvents"},"tools":[{"id":"c2a17f17-f391-49e3-8aeb-f30c94793727","type":"PanTool"},{"id":"b34e8e87-1b76-4e53-8f7b-1b4921cd9a22","type":"BoxZoomTool"},{"id":"d242b099-13de-444c-ab31-3f7fb2807765","type":"WheelZoomTool"},{"id":"1f755c8a-0e4a-49ad-97bb-3257be79dceb","type":"ResetTool"},{"id":"0a5f61a6-4d16-42f4-a433-d9fea32418ad","type":"ResizeTool"}],"x_range":{"id":"e595dd21-352e-47eb-af1a-1c8fbe8f8738","type":"Range1d"},"y_range":{"id":"5086e76a-4fa1-4ffb-af8f-0c0322fdaa5d","type":"Range1d"}},"id":"3c6a669e-3d00-4393-bff7-a0c6858dc0e0","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"2c4aeb4e-e2e5-4553-983e-66ac301614e5","type":"BoxAnnotation"},"plot":{"id":"9d8a8231-37f6-4ed3-a42a-80bc4cd5f5e5","subtype":"Figure","type":"Plot"}},"id":"9fe54a04-12a9-4fd8-96e4-19ede628a505","type":"BoxZoomTool"},{"attributes":{"axis_label":"Variance","formatter":{"id":"1603dd8d-45b4-460a-be39-5e3f5bbb6d25","type":"BasicTickFormatter"},"plot":{"id":"a2493ead-074d-452e-b6f7-f0b090533534","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b927e6f-805d-4f7a-a361-de3e087ee9e3","type":"BasicTicker"}},"id":"0b91020d-a572-4064-85a8-b3ef5e92cf13","type":"LinearAxis"},{"attributes":{},"id":"cfb172c9-18a0-4a68-996f-3dfd7d8d5e00","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"navy"},"line_color":{"value":"navy"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a9f4539e-8ea9-4d84-b46e-1149811e8ca2","type":"Circle"},{"attributes":{},"id":"6b28789b-8557-49a1-8925-254c6c760b3d","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b45f375e-a0ff-404b-92ef-f57f33913721","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"ec38bea4-c10c-4db2-9d5d-b8200cf87da7","type":"LinearAxis"}],"left":[{"id":"489ee919-8733-4644-805c-5d6d7c41e667","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"ec38bea4-c10c-4db2-9d5d-b8200cf87da7","type":"LinearAxis"},{"id":"8fe63220-84b9-474e-807f-e6c5adeb50be","type":"Grid"},{"id":"489ee919-8733-4644-805c-5d6d7c41e667","type":"LinearAxis"},{"id":"08c91418-bc3c-4189-9839-ef06c8f079f6","type":"Grid"},{"id":"fccf5ea3-3f40-4ff5-a8de-35775a87ba6b","type":"BoxAnnotation"},{"id":"e757633c-b067-4451-8d10-69795cb6ba7a","type":"GlyphRende ...
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="16d2f6be-855f-4c49-a5f7-c7a911552738">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="3448d9ce-9646-4622-ba75-fba89af83b37"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3448d9ce-9646-4622-ba75-fba89af83b37");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3448d9ce-9646-4622-ba75-fba89af83b37' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cf36c336-ba2e-4cc2-90ed-017c6d0a145a":{"roots":{"references":[{"attributes":{"callback":null,"end":14.82232333146906,"start":6.945731267469336},"id":"1fd7be20-6c23-4db6-81aa-e2e82c9b7d6d","type":"Range1d"},{"attributes":{"axis_label":"Variance","formatter":{"id":"a9d5afdb-9158-4971-990c-59939011eb98","type":"BasicTickFormatter"},"plot":{"id":"471e951e-2c74-4c95-9c72-01a26e886c5a","subtype":"Figure","type":"Plot"},"ticker":{"id":"71d52991-182e-487c-b992-0b5a87eed166","type":"BasicTicker"}},"id":"7569e9de-4161-45a3-9d12-393b4f7b4048","type":"LinearAxis"},{"attributes":{"below":[{"id":"bcd5b5be-6dcc-402b-8ed9-1db5aa2a4a96","type":"LinearAxis"}],"left":[{"id":"31f12798-0de4-4e88-9d46-b22dc016e2b3","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"bcd5b5be-6dcc-402b-8ed9-1db5aa2a4a96","type":"LinearAxis"},{"id":"4b0013aa-9b70-4ca3-b9a9-e55dcb862b57","type":"Grid"},{"id":"31f12798-0de4-4e88-9d46-b22dc016e2b3","type":"LinearAxis"},{"id":"68c69ce1-112d-48c8-8891-22f82af