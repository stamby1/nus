# %%
import json
import itertools
from bokeh.plotting import figure, show, vplot, gridplot
from bokeh.io import output_notebook
from bokeh.models import LinearAxis, Range1d, BoxAnnotation, GridPlot
from pykalman import KalmanFilter
import numpy as np

# %%
class SimpleFilter(object):
    # extend filter
    def __init__(self):
        self.eest = 10  # error in estimate - given
        self.emea = 10  # error in measurement - given and doesn't change
        self.est = 10  # current estimate - given
        self.mea = -1  # current measurement - given
        
        self.kg = -1  # kalman gain - calculate
        self.prev_est = -1  # previous estimate - base case = est
        self.prev_eest = -1

    def __str__(self):
        return str(self.val)

    def __repr__(self):
        return str(self.val)

    def put(self, val):
        self.mea = val  # set current measurement
        
        # calculate kalman gain
        self.kg = self.eest/(self.eest + self.emea)
        
        # calculate current estimate
        self.prev_est = self.est
        self.est = self.prev_est + (self.kg*(self.mea - self.prev_est))
        
        # calculate the new estimate error
        self.prev_eest = self.eest
        self.eest = (1-self.kg) * (self.prev_eest)
        
    #def get(val):
    def get(self):
        return self.est

# %%
# global variables
initial_time = 0
times = []
filterD = []
filterR = []
begin = []
end = []
plots = []
original = []

# %%
def plot_minor(b):
    global times
    global filterD
    global filterR
    global begin
    global end
    global initial_time
    global original
    global plots
    tempTitle="Beacon 0:" + str(b)
    
    output_notebook()
    p = figure(
        tools="pan, box_zoom, wheel_zoom, reset, resize",
        title=tempTitle, x_axis_label='Time Elapsed (seconds)', y_axis_label='Distance (m)',
        x_range=((min(begin)-initial_time)/1000, (max(end)-initial_time)/1000), y_range=(0, max(original)),
        plot_width=900, plot_height=400
    )
    
    for i in range(len(begin)):
        box = BoxAnnotation(
            plot=p,
            left=(begin[i]-initial_time)/1000,
            right=(end[i]-initial_time)/1000,
            fill_alpha=0.1,
            fill_color='grey'
        )
        p.renderers.extend([box])
        
    p.scatter(
        times, original, marker="circle",
        fill_color="firebrick", line_color="firebrick",
        fill_alpha=0.4, legend="Unfiltered"
    )
    
    p.line(
        times, filterD, 
        line_color = "navy", line_width=3,
        legend="Filtered (Kalman)"
    )
    #p.line(times, original, line_color = "firebrick")
    
    '''
    p.extra_y_ranges = {"RSSI": Range1d(start=-100, end=0)}  # add y axis for rssi
    p.line(
        times, filterR,
        line_color = "firebrick", y_range_name="RSSI", legend="Filtered RSSI"
    )
    p.add_layout(LinearAxis(y_range_name="RSSI", axis_label="RSSI"), 'left')
    '''
     
    #plots.append(p)
    show(p)

# %%
def get_data(i):  # open text file and extract data
    global initial_time
    global times
    global filterD
    global filterR
    global original
    
    #textName = "minor" + str(i) + ".txt"
    textName = "2_6_2016_1441.txt"
    tempName = "0:" + str(i)
    f = open(textName)
    first = True
    pos = 0
    tempD = SimpleFilter()
    tempR = SimpleFilter()
    times[:] = []
    original[:] = []
    filterD[:] = []
    filterR[:] = []
    for line in f:
        words = line.split()
        time = int(words[0])  # get time
        if first == True:
            initial_time = time  # set base time
            first = False
        time = (time - initial_time) / 1000  # get elapsed time in seconds
        parsed_json = json.loads(words[1])  # parse json
        if parsed_json.get('node') and parsed_json['minor'] == i:
            beaconNum = str(parsed_json['major']) + ":" + str(parsed_json['minor'])  # beacon identified by major and minor
            rssi = parsed_json['rssi']
            distance = 10**((rssi+60)/-20)  # log-distance pathloss model
            tempD.put(distance)
            tempR.put(rssi)
            #val = kalman_filter(distance)
            filterD.append(tempD.get())
            filterR.append(tempR.get())
            times.append(time)
            original.append(distance)
    f.close()  # close file

# %%
def get_markers():
    global begin
    global end
    m = open("markers.txt")
    for line in m:
        words = line.split()
        time = int(words[0])  # get raw time
        parsed_json = json.loads(words[1])  # parse json
        if parsed_json['marker'] == "begin\n":
            begin.append(time)
        elif parsed_json['marker'] == "end\n":
            end.append(time)
    m.close()

# %%
def main():
    global plots
    global times
    
    plots.clear()
    
    get_markers()
    
    for i in range(7):
        get_data(i)
        plot_minor(i)
    
    #output_notebook()
    #grid = gridplot([plots])
    #grid = gridplot([plots[0:2], plots[2:4], plots[4:6], plots[6:8]])
    #show(grid)

# %%
if __name__ == "__main__":
    main()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6a83bac9-7694-4233-aa95-f060f16a4314">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="abf6fe6b-91e5-4a7a-94c0-1a2c03445573"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("abf6fe6b-91e5-4a7a-94c0-1a2c03445573");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'abf6fe6b-91e5-4a7a-94c0-1a2c03445573' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"62eecf8d-9260-4393-bcf1-4f7f42d9ea7d":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"grey"},"left":285.212,"plot":{"id":"8b568e1d-3d7f-44ab-80d1-f8bebee06c74","subtype":"Figure","type":"Plot"},"right":306.083},"id":"43fd9c8e-c973-4cb0-b5b2-231442ecd3fb","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.004,0.425,0.534,0.742,0.979,1.055,1.161,1.373,1.475,1.584,1.793,1.893,1.999,2.117,2.215,2.412,2.519,2.623,3.182,3.276,3.496,3.591,3.699,4.116,4.219,4.43,4.647,4.857,4.982,5.062,5.169,5.27,5.376,5.481,5.588,5.945,5.946,5.979,6.01,6.114,6.33,6.439,6.538,6.645,6.746,6.855,7.075,7.619,7.7,7.907,8.115,8.322,8.425,8.536,8.638,8.746,8.851,8.962,9.065,9.302,9.404,9.621,9.725,9.811,9.938,10.02,10.131,10.242,10.655,10.869,11.082,11.201,11.422,11.501,11.932,12.135,12.242,13.085,13.177,13.292,13.397,13.506,13.607,13.923,14.029,14.151,14.235,14.346,14.551,14.777,14.982,15.289,15.396,15.606,15.712,15.817,15.935,16.032,16.138,16.343,16.548,16.647,16.752,16.972,17.077,17.192,17.382,17.49,17.591,17.692,17.791,17.899,18.008,18.111,18.327,18.431,18.636,18.74,18.841,18.945,19.159,19.37,19.478,19.579,19.687,19.794,19.897,20.105,20.419,20.528,20.634,20.756,20.838,21.051,21.155,21.262,21.364,21.685,21.789,21.898,22.008,22.327,22.636,22.74,22.847,22.949,23.051,23.156,23.359,23.464,23.57,23.677,23.781,23.886,23.991,24.102,24.398,24.606,24.71,24.808,25.117,25.226,25.355,25.434,25.765,25.955,26.059,26.168,26.27,26.68,26.895,27.001,27.122,27.315,27.405,27.506,27.61,27.712,27.815,28.129,28.338,28.549,28.657,28.869,28.979,29.084,29.195,29.305,29.405,29.731,29.916,30.129,30.231,30.345,30.441,30.548,30.655,30.864,30.982,31.072,31.201,31.492,31.704,32.021,32.126,32.227,32.334,32.441,32.582,32.895,33.0,33.081,33.292,34.045,34.468,34.681,34.789,34.987,35.1,35.298,35.514,35.622,35.721,35.942,36.155,36.365,36.46,36.564,36.667,36.785,36.88,36.988,37.086,37.
ecb-c8b9-4697-a79d-82663a5dfac6","type":"BoxAnnotation"},{"id":"089606b5-58af-4426-98c2-d8588470ed70","type":"Legend"},{"id":"84675586-2d1f-4597-953e-2731c2640dfd","type":"GlyphRenderer"},{"id":"6649041b-f2e1-427e-804e-cc70853da699","type":"GlyphRenderer"}],"title":"Beacon 0:5","tool_events":{"id":"45ff6fd6-86f6-4581-95ed-2b4dff629354","type":"ToolEvents"},"tools":[{"id":"8818b2c2-de5f-439c-a817-d4a2562da3fb","type":"PanTool"},{"id":"2c2ce603-6c7b-412b-81f0-f00c4f6bec9e","type":"BoxZoomTool"},{"id":"7f9bd644-dac2-4aa2-adc7-5fd19c2d200d","type":"WheelZoomTool"},{"id":"7ad54072-352c-457b-a690-eb7df2f85d6d","type":"ResetTool"},{"id":"cff33526-8e40-4dad-b051-0986963d1f3b","type":"ResizeTool"}],"x_range":{"id":"05a3e920-2e36-4b35-a4b0-0daf1df950b9","type":"Range1d"},"y_range":{"id":"74365dd5-668b-45e2-9206-cc29462359cd","type":"Range1d"}},"id":"bef56c41-c2a6-4e20-ab20-80668417fdc3","subtype":"Figure","type":"Plot"},{"attributes":{"legends":[["Unfiltered",[{"id":"aff8c1ca-77f6-47fd-953f-e3d80a2f272e","type":"GlyphRenderer"}]],["Filtered (Kalman)",[{"id":"6bbe93d7-699b-4a67-bb7c-e51f3945e3d2","type":"GlyphRenderer"}]]],"plot":{"id":"8b568e1d-3d7f-44ab-80d1-f8bebee06c74","subtype":"Figure","type":"Plot"}},"id":"0303bc1b-e5ba-46b0-b199-5c471d1a660e","type":"Legend"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2 ...
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="31845c6c-41c3-4411-a8ed-370c872f7685">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="ba559293-0a3e-4a11-8525-cb8ee8bb76b4"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ba559293-0a3e-4a11-8525-cb8ee8bb76b4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ba559293-0a3e-4a11-8525-cb8ee8bb76b4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"abaf03cb-8c1f-4799-b193-adb6aff9aace":{"roots":{"references":[{"attributes":{},"id":"35b106d7-16db-4831-9ce5-de25fdda5529","type":"BasicTickFormatter"},{"attributes":{},"id":"94faaf05-80b5-4c3f-a8a4-ad6ea6fb2e70","type":"BasicTicker"},{"attributes":{},"id":"45ff6fd6-86f6-4581-95ed-2b4dff629354","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"grey"},"left":4.892,"plot":{"id":"8b568e1d-3d7f-44ab-80d1-f8bebee06c74","subtype":"Figure","type":"Plot"},"right":27.491},"id":"2abdd527-fd31-4e31-8234-efa16affa91a","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"grey"},"left":4.892,"plot":{"id":"264635c0-bf90-4544-8bf2-ff8ee74a3201","subtype":"Figure","type":"Plot"},"right":27.491},"id":"29ce43f9-0d32-4343-a667-08fd76a6cbff","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"92c62bce-70d4-4391-a787-9f1a1faa0ab5","subtype":"Figure","type":"Plot"},"ticker":{"id":"94faaf05-80b5-4c3f-a8a4-ad6ea6fb2e70","type":"BasicTicker"}},"id":"cc50fe58-35e8-4dfc-8eb3-194c33082241","type":"Grid"},{"attributes":{"axis_label":"Distance (m)","formatter":{"id":"9386fcb9-f11a-43d2-8667-362bfdec3ba6","type":"BasicTickFormatter"},"plot":{"id":"61fc5a9d-df17-42ba-ab38-24bf81a3b649","subtype":"Figure","type":"Plot"},"ticker":{"id":"811d4d